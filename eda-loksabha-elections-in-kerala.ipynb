# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../input/india-loksabha-elections-data19622019/Loksabha_election_data_1962-2019')
df.head()
# Out:
#       Pc_name   no type                        state  \
# 0    Adilabad   36  GEN               Andhra Pradesh
# 1       Adoni   27  GEN               Andhra Pradesh
# 2        Agra  433  GEN  Uttar Pradesh [1947 - 1999]
# 3   Ahmedabad  120  GEN                      Gujarat
# 4  Ahmednagar  245  GEN                  Maharashtra
#
#                candidate_name                             party  electors  \
# 0            G. Narayan Reddy          Indian National Congress  404283.0
# 1  Pendekanti Venkatasubbaiah          Indian National Congress  419077.0
# 2            Seth Achal Singh          Indian National Congress  433164.0
# 3   Indulal Kanaiyalal Yagnik  Nutan Maha Gujarat Janta Parisha  433392.0
# 4   Motilal Kundanmal Firodya          Indian National Congress  403913.0
#
#       votes  turnout  margin  margin%  year
# 0  220383.0     54.5  89,085     40.4  1962
# 1  252379.0     60.2  33,022     13.1  1962
# 2  275663.0     63.6  54,351     19.7  1962
# ...

# %%
df['margin']=df['margin'].str.replace(',', '').astype(float)

# %%
# Using group by to group elements based on groups
yr=df.groupby('year')
yr

# %%
#Printing first elements of groups formed
year=yr.first()
years=year.index
year
# Out:
#               Pc_name   no type                      state  \
# year
# 1962         Adilabad   36  GEN             Andhra Pradesh
# 1967         Adilabad   35  GEN             Andhra Pradesh
# 1971  A And N Islands  501  GEN  Andaman & Nicobar Islands
# 1977         Adilabad   35  GEN             Andhra Pradesh
# 1980         Adilabad   35  GEN             Andhra Pradesh
# 1984         Adilabad   35  GEN             Andhra Pradesh
# 1989         Adilabad   35  GEN             Andhra Pradesh
# 1991         Adilabad   35  GEN             Andhra Pradesh
# 1996         Adilabad   35  GEN             Andhra Pradesh
# 1998         Adilabad   35  GEN             Andhra Pradesh
# 1999         Adilabad   35  GEN             Andhra Pradesh
# 2004         Adilabad   35  GEN             Andhra Pradesh
# 2009         Adilabad    1   ST             Andhra Pradesh
# 2014         Adilabad    1   ST                  Telangana
# 2019         Adilabad    1   ST                  Telangana
#
# ...

# %%
# Showing the results in the year 2019
yr.get_group(2019)
# Out:
#              Pc_name  no type                         state  \
# 7505        Adilabad   1   ST                     Telangana
# 7506            Agra  18   SC  Uttar Pradesh [2000 Onwards]
# 7507      Ahmadnagar  37  GEN                   Maharashtra
# 7508  Ahmedabad East   7  GEN                       Gujarat
# 7509  Ahmedabad West   8   SC                       Gujarat
# ...              ...  ..  ...                           ...
# 8041          Wardha   8  GEN                   Maharashtra
# 8042         Wayanad   4  GEN                        Kerala
# 8043      West Delhi   6  GEN          Delhi [1977 Onwards]
# 8044  Yavatmal-Washi  14  GEN                   Maharashtra
# 8045       Zahirabad   5  GEN                     Telangana
#
#                          candidate_name                      party   electors  \
# 7505                     Soyam Bapu Rao      Bharatiya Janta Party  1382837.0
# 7506              Satyapal Singh Baghel      Bharatiya Janta Party  1866262.0
# ...

# %%
# using group by to group based on 3 columns ; state,year and paty
styr = df.groupby(['state', 'year'])
styr.first()
# Out:
#                                                   Pc_name   no type  \
# state                     year
# Andaman & Nicobar Islands 1967            Andaman Nicobar  497  GEN
#                           1971            A And N Islands  501  GEN
#                           1977  Andaman & Nicobar Islands    1  GEN
#                           1980  Andaman & Nicobar Islands    1  GEN
#                           1984  Andaman & Nicobar Islands    1  GEN
# ...                                                   ...  ...  ...
# West Bengal               1999                Alipurduars    2   ST
#                           2004                Alipurduars    2   ST
#                           2009                Alipurduars    2   ST
#                           2014                Alipurduars    2   ST
#                           2019                Alipurduars    2   ST
#
#                                    candidate_name  \
# state                     year
# ...

# %%
styr.count()
# Out:
#                                 Pc_name  no  type  candidate_name  party  \
# state                     year
# Andaman & Nicobar Islands 1967        1   1     1               1      1
#                           1971        1   1     1               1      1
#                           1977        1   1     1               1      1
#                           1980        1   1     1               1      1
#                           1984        1   1     1               1      1
# ...                                 ...  ..   ...             ...    ...
# West Bengal               1999       42  42    42              42     42
#                           2004       42  42    42              42     42
#                           2009       42  42    42              42     42
#                           2014       42  42    42              42     42
#                           2019       42  42    42              42     42
#
# ...

# %%
styr.size()
# Out:
# state                      year
# Andaman & Nicobar Islands  1967     1
#                            1971     1
#                            1977     1
#                            1980     1
#                            1984     1
#                                    ..
# West Bengal                1999    42
#                            2004    42
#                            2009    42
#                            2014    42
#                            2019    42
# Length: 470, dtype: int64

# %%
k19=styr.get_group(('Kerala',2019))

# %%
k19
# Out:
#              Pc_name  no type   state          candidate_name  \
# 7513       Alappuzha  15  GEN  Kerala          Adv. A M Ariff
# 7514         Alathur   9   SC  Kerala           Ramya Haridas
# 7545        Attingal  19  GEN  Kerala      Adv. Adoor Prakash
# 7619       Chalakudy  11  GEN  Kerala           Benny Behanan
# 7672       Ernakulam  12  GEN  Kerala               Hibi Eden
# 7725          Idukki  13  GEN  Kerala     Adv. Dean Kuriakose
# 7772          Kannur   2  GEN  Kerala           K. Sudhakaran
# 7780       Kasaragod   1  GEN  Kerala       Rajmohan Unnithan
# 7801          Kollam  18  GEN  Kerala       N.K.Premachandran
# 7806        Kottayam  14  GEN  Kerala      Thomas Chazhikadan
# 7807       Kozhikode   5  GEN  Kerala            M.K.Raghavan
# 7834      Malappuram   6  GEN  Kerala       P.K. Kunhalikutty
# 7846     Mavelikkara  16   SC  Kerala       Kodikunnil Suresh
# 7899        Palakkad   8  GEN  Kerala          V K Sreekandan
# ...

# %%
k19.plot(x='Pc_name',y=['margin','votes','electors'])
# Out:
# <AxesSubplot:xlabel='Pc_name'>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# creating a coustom colour pallete
# visit http://colormind.io/ to get color codes you neeed
top='#9E1C00'
mid='#F8E506'
low='#1CA4A4'

# %%
# list of colors to use
col=[low,mid,top]

# %%
#plotting bar chart
k19.plot(x='Pc_name',y=['margin','electors','votes'],kind='bar',figsize=(16,8.5),width=.9,color=col)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
co19=k19.groupby('party').count()

# %%
exp=[]
gg=co19.index
for i in gg:
    print(i)
    exp.append(.03)
exp
# Out:
# Communist Party Of India (Marxist)
# Indian National Congress
# Indian Union Muslim League
# Kerala Congress(M)
# Revolutionary Socialist Party
# [0.03, 0.03, 0.03, 0.03, 0.03]

# %%
tmc='#FFF900'
bsp='#31a5fb'
bjp='#ff8c00'
cpi='#ff009f'
cpm='#ff0000'
inc='#083df3'
ncp='#4e2c81'

lstcol=[tmc,bsp,bjp,cpi,cpm,inc,ncp]

# %%
explode = (0.3, 0.0, 0.3, 0.3, 0.3)

# Wedge properties
wp = { 'linewidth' : 2, 'edgecolor' : "white" }

  
# Creating autocpt arguments
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:d} ".format( absolute)

# Creating plot
fig, ax = plt.subplots(figsize =(20, 7))
wedges, texts, autotexts = ax.pie(co19.votes, 
                                  autopct = lambda pct: func(pct, co19.votes),
                                  explode = explode, 
                                  labels = co19.index,
                                  shadow = True,
                                  colors = lstcol,
                                  startangle = 180,
                                  wedgeprops = wp,
                                  textprops = dict(color ="#173A40"))

# Adding legend
ax.legend(wedges, co19.index,
          title ="Parties",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))
 

plt.setp(autotexts, size = 8, weight ="bold")
ax.set_title("Political parties and their seats in 2019")
  
# show plot
plt.show()

# %%
years
# Out:
# Int64Index([1962, 1967, 1971, 1977, 1980, 1984, 1989, 1991, 1996, 1998, 1999,
#             2004, 2009, 2014, 2019],
#            dtype='int64', name='year')

# %%
#combining the above visualisations to show the results in kerala over the years
print('Loksabha elections in kerala - an overview')
for yr in years:
    #display('kerala_'+str(yr))
    n1=pd.DataFrame()
    n1=styr.get_group(('Kerala',yr))
    #display(n1)
    
    #plotting bar chart
    n1.plot(x='Pc_name',y=['margin','electors','votes'],kind='bar',figsize=(16,8.5),width=.9,color=col)
    plt.show
    print(yr)
    
    co19=n1.groupby('party').count()
    
    explode=[]
    exp=co19.index
    for i in exp:
        explode.append(0.1)
    explode.pop()
    explode.append(0)
        
    
    #explode = (0.3, 0.0, 0.3, 0.3, 0.3)

    # Wedge properties
    wp = { 'linewidth' : 2, 'edgecolor' : "white" }

  
    # Creating autocpt arguments
    def func(pct, allvalues):
        absolute = int(pct / 100.*np.sum(allvalues))
        return "{:d} ".format( absolute)

    # Creating plot
    fig, ax = plt.subplots(figsize =(20, 7))
    wedges, texts, autotexts = ax.pie(co19.votes, 
                                  autopct = lambda pct: func(pct, co19.votes),
                                  explode = explode, 
                                  labels = co19.index,
                                  shadow = True,
                                  colors = lstcol,
                                  startangle = 180,
                                  wedgeprops = wp,
                                  textprops = dict(color ="#173A40"))

    # Adding legend
    ax.legend(wedges, exp,
          title ="Parties",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))
 

    plt.setp(autotexts, size = 8, weight ="bold")
    ax.set_title("Political parties and their seats in "+str(yr))
  
    # show plot
    plt.show()
# Out:
# Loksabha elections in kerala - an overview
# 1962
# 1967
# 1971
# 1977
# 1980
# 1984
# 1989
# 1991
# 1996
# 1998
# 1999
# 2004
# 2009
# 2014
# 2019

# %%
seatyr=df.groupby(['party','year']).count()

# %%
seatyr.index
# Out:
# MultiIndex([(                         'Aam Aadmi Party', 2014),
#             (                         'Aam Aadmi Party', 2019),
#             (                               'Akali Dal', 1962),
#             (      'Akali Dal - Sant Fateh Singh Group', 1967),
#             (         'Akhil Bharatiya Hindu Mahasabha', 1962),
#             (         'Akhil Bharatiya Hindu Mahasabha', 1989),
#             (      'Akhil Bharatiya Ram Rajya Parishad', 1962),
#             (     'Akhil Bhartiya Lok Tantrik Congress', 1999),
#             ('All India Anna Dravida Munnetra Kazhagam', 1977),
#             ('All India Anna Dravida Munnetra Kazhagam', 1980),
#             ...
#             (           'United Goans - Seqveria Group', 1971),
#             (           'United Goans Democratic Party', 1996),
#             (          'United Minorities Front, Assam', 1998),
#             (                          'Utkal Congress', 1971),
# ...

# %%
seatyr['votes']
# Out:
# party                                  year
# Aam Aadmi Party                        2014     4
#                                        2019     1
# Akali Dal                              1962     3
# Akali Dal - Sant Fateh Singh Group     1967     3
# Akhil Bharatiya Hindu Mahasabha        1962     1
#                                                ..
# Viduthalai Chiruthaigal Katchi         2019     1
# Vishal Haryana                         1971     1
# West Bengal Trinamool Congress         1998     7
# Yuvajana Sramika Rythu Congress Party  2014     9
#                                        2019    22
# Name: votes, Length: 431, dtype: int64

# %%
md = seatyr.reset_index()
md.head(3)
# Out:
#              party  year  Pc_name  no  type  state  candidate_name  electors  \
# 0  Aam Aadmi Party  2014        4   4     4      4               4         4
# 1  Aam Aadmi Party  2019        1   1     1      1               1         1
# 2        Akali Dal  1962        3   3     3      3               3         3
#
#    votes  turnout  margin  margin%
# 0      4        4       4        4
# 1      1        1       1        1
# 2      3        3       3        3

# %%
seats=md.drop(['Pc_name','type','candidate_name','electors','turnout','margin','margin%','state','votes'],axis=1)
seats.head()
# Out:
#                                 party  year  no
# 0                     Aam Aadmi Party  2014   4
# 1                     Aam Aadmi Party  2019   1
# 2                           Akali Dal  1962   3
# 3  Akali Dal - Sant Fateh Singh Group  1967   3
# 4     Akhil Bharatiya Hindu Mahasabha  1962   1

# %%
seats.rename(columns={'no':'seats'},inplace=True)
seats
# Out:
#                                      party  year  seats
# 0                          Aam Aadmi Party  2014      4
# 1                          Aam Aadmi Party  2019      1
# 2                                Akali Dal  1962      3
# 3       Akali Dal - Sant Fateh Singh Group  1967      3
# 4          Akhil Bharatiya Hindu Mahasabha  1962      1
# ..                                     ...   ...    ...
# 426         Viduthalai Chiruthaigal Katchi  2019      1
# 427                         Vishal Haryana  1971      1
# 428         West Bengal Trinamool Congress  1998      7
# 429  Yuvajana Sramika Rythu Congress Party  2014      9
# 430  Yuvajana Sramika Rythu Congress Party  2019     22
#
# [431 rows x 3 columns]

# %%
national_parties=['Indian National Congress','Bharatiya Janta Party','All India Trinamool Congress','Bahujan Samaj Party','Communist Party Of India','Communist Party Of India (MARXIST)','Nationalist Congress Party']

# %%
bjp_con=seats.loc[seats['party'].isin(national_parties)]

# %%
import seaborn as sns

# %%
tmc='#FFF900'
bsp='#31a5fb'
bjp='#ff8c00'
cpi='#ff009f'
cpm='#ff0000'
inc='#083df3'
ncp='#4e2c81'

lstcol=[tmc,bsp,bjp,cpi,cpm,inc,ncp]

# %%
fig, ax = plt.subplots(figsize=(12, 7))
sns.lineplot(data=bjp_con, x="year", y="seats", hue="party",palette=lstcol,linewidth = 2.5)
plt.legend( bbox_to_anchor=(1.02, 1),loc='upper left', borderaxespad=0, title='Party')
plt.title('Trend of Loksabha seats over the years of Recognized National Parties')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
